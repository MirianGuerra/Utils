# %%
import pandas as pd
df_origem = pd.read_csv('/home/hacpom03/Documentos/GWAS/checksums.md5', delim_whitespace=True, on_bad_lines='warn')
df_origem
# Out:
# Skipping line 55: expected 2 fields, saw 4
# Skipping line 60: expected 2 fields, saw 3
#      83bb917bbeafa7008747135f3d545d4e  \
# 0    972a5fd5e19c92ce8c457ee13c4d8833
# 1    a102b11c09cf4f795c5b277066d2feb4
# 2    85a7910bdc043544a726ee5d8ad53067
# 3    4c07970ccb59a2bf876e1807473969c8
# 4    de4e0b2dea1c39490cde795a8276302d
# ..                                ...
# 99   5aec8beb7a9c6fae5246d80f5eede575
# 100  2f444a7aed538aaf3e5cd06f9bec4267
# 101  7f01abedca66b3e4b080d1a8e98203f1
# 102  34afdbf5dcc656fb10f8570b7913216e
# 103  6be0d332f9fafaf9ea2ca5f365e11e01
#
#     ./AxiomReference/Allele_naming_convention_Affymetrix_Axiom.pdf
# 0      ./AxiomReference/Axiom_Library_Files_Basics.pdf
# 1    ./AxiomReference/Axiom_PMDA.na36.r8.a9.af_supp...
# 2    ./AxiomReference/Axiom_PMDA.na36.r8.a9.annot.c...
# 3    ./AxiomReference/Axiom_PMDA.na36.r8.a9.annot.d...
# 4        ./AxiomReference/Axiom_PMDA.na36.r8.a9.bed.gz
# ..                                                 ...
# ...
